# %%
import pandas as pd

# %%
data = pd.read_csv('nba.csv')

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data.Name
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
data.Name.values
# Out:
# array(['Avery Bradley', 'Jae Crowder', 'John Holland', 'R.J. Hunter',
#        'Jonas Jerebko', 'Amir Johnson', 'Jordan Mickey', 'Kelly Olynyk',
#        'Terry Rozier', 'Marcus Smart', 'Jared Sullinger', 'Isaiah Thomas',
#        'Evan Turner', 'James Young', 'Tyler Zeller', 'Bojan Bogdanovic',
#        'Markel Brown', 'Wayne Ellington', 'Rondae Hollis-Jefferson',
#        'Jarrett Jack', 'Sergey Karasev', 'Sean Kilpatrick',
#        'Shane Larkin', 'Brook Lopez', 'Chris McCullough', 'Willie Reed',
#        'Thomas Robinson', 'Henry Sims', 'Donald Sloan', 'Thaddeus Young',
#        'Arron Afflalo', 'Lou Amundson', 'Thanasis Antetokounmpo',
#        'Carmelo Anthony', 'Jose Calderon', 'Cleanthony Early',
#        'Langston Galloway', 'Jerian Grant', 'Robin Lopez', "Kyle O'Quinn",
#        'Kristaps Porzingis', 'Kevin Seraphin', 'Lance Thomas',
#        'Sasha Vujacic', 'Derrick Williams', 'Tony Wroten', 'Elton Brand',
# ...

# %%
data.Team.head(8)
# Out:
# 0    Boston Celtics
# 1    Boston Celtics
# 2    Boston Celtics
# 3    Boston Celtics
# 4    Boston Celtics
# 5    Boston Celtics
# 6    Boston Celtics
# 7    Boston Celtics
# Name: Team, dtype: object

# %%
data[['Name', 'Team']]
# Out:
#               Name            Team
# 0    Avery Bradley  Boston Celtics
# 1      Jae Crowder  Boston Celtics
# 2     John Holland  Boston Celtics
# 3      R.J. Hunter  Boston Celtics
# 4    Jonas Jerebko  Boston Celtics
# ..             ...             ...
# 453   Shelvin Mack       Utah Jazz
# 454      Raul Neto       Utah Jazz
# 455   Tibor Pleiss       Utah Jazz
# 456    Jeff Withey       Utah Jazz
# 457            NaN             NaN
#
# [458 rows x 2 columns]

# %%
data[["Team","Name"]].head(8)
# Out:
#              Team           Name
# 0  Boston Celtics  Avery Bradley
# 1  Boston Celtics    Jae Crowder
# 2  Boston Celtics   John Holland
# 3  Boston Celtics    R.J. Hunter
# 4  Boston Celtics  Jonas Jerebko
# 5  Boston Celtics   Amir Johnson
# 6  Boston Celtics  Jordan Mickey
# 7  Boston Celtics   Kelly Olynyk

# %%
data["Sport"] = "Basketball"

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball
# 3      Georgia State  1148640.0  Basketball
# 4                NaN  5000000.0  Basketball

# %%
data = pd.read_csv('nba.csv')

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data.insert(loc = 3, column = "Sport", value = "Basketball")

# %%
data.head()
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0  Basketball       PF  29.0   6-10
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN
# 3   185.0      Georgia State  1148640.0
# 4   231.0                NaN  5000000.0

# %%
data = pd.read_csv('nba.csv')

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data["Age"] + 10
# Out:
# 0      35.0
# 1      35.0
# 2      37.0
# 3      32.0
# 4      39.0
#        ...
# 453    36.0
# 454    34.0
# 455    36.0
# 456    36.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
data["Age in a decade"] = data["Age"] + 10

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  Age in a decade
# 0              Texas  7730337.0             35.0
# 1          Marquette  6796117.0             35.0
# 2  Boston University        NaN             37.0
# 3      Georgia State  1148640.0             32.0
# 4                NaN  5000000.0             39.0

# %%
data.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary  Age in a decade
# 453  2433333.0             36.0
# 454   900000.0             34.0
# 455  2900000.0             36.0
# 456   947276.0             36.0
# 457        NaN              NaN

# %%
data.dropna(how = "all")
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary  Age in a decade
# ...

# %%
data.dropna(subset = ["College"])
data.dropna(subset = ["College", "Salary"])
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary  Age in a decade
# ...

# %%
data["College"]=data["College"].fillna("Unknown")

# %%
data.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight  College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0   Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0  Unknown
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0  Unknown
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0   Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN  Unknown
#
#         Salary  Age in a decade
# 453  2433333.0             36.0
# 454   900000.0             34.0
# 455  2900000.0             36.0
# 456   947276.0             36.0
# 457        NaN              NaN

# %%
data = data.dropna(how = "all")

# %%
data.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
data["Age"] = data["Age"].astype("int")

# %%
data.head()
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG   27    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG   22    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF   29   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data["Position"].nunique()
# Out:
# 5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(3), int32(1), object(5)
# memory usage: 33.9+ KB

# %%
data["Position"] = data["Position"].astype("category")

# %%
data.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age           int32
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    category
#  4   Age       457 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: category(1), float64(3), int32(1), object(4)
# memory usage: 31.0+ KB

# %%
data["Team"].nunique()
# Out:
# 30

# %%
data["Team"] = data["Team"].astype("category")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    category
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    category
#  4   Age       457 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: category(2), float64(3), int32(1), object(3)
# memory usage: 29.2+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    category
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    category
#  4   Age       457 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: category(2), float64(3), int32(1), object(3)
# memory usage: 29.2+ KB

# %%
data["Name"]
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 452       Trey Lyles
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# Name: Name, Length: 457, dtype: object

# %%
data["Name"].sort_values()
# Out:
# 152       Aaron Brooks
# 356       Aaron Gordon
# 328     Aaron Harrison
# 404      Adreian Payne
# 312         Al Horford
#             ...
# 386    Wilson Chandler
# 270     Xavier Munford
# 402        Zach LaVine
# 271      Zach Randolph
# 237      Zaza Pachulia
# Name: Name, Length: 457, dtype: object

# %%
data.sort_values(by = "Name")
# Out:
#                 Name                    Team  Number Position  Age Height  \
# 152     Aaron Brooks           Chicago Bulls     0.0       PG   31    6-0
# 356     Aaron Gordon           Orlando Magic     0.0       PF   20    6-9
# 328   Aaron Harrison       Charlotte Hornets     9.0       SG   21    6-6
# 404    Adreian Payne  Minnesota Timberwolves    33.0       PF   25   6-10
# 312       Al Horford           Atlanta Hawks    15.0        C   30   6-10
# ..               ...                     ...     ...      ...  ...    ...
# 386  Wilson Chandler          Denver Nuggets    21.0       SF   29    6-8
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG   24    6-3
# 402      Zach LaVine  Minnesota Timberwolves     8.0       PG   21    6-5
# 271    Zach Randolph       Memphis Grizzlies    50.0       PF   34    6-9
# 237    Zaza Pachulia        Dallas Mavericks    27.0        C   32   6-11
#
#      Weight         College      Salary
# ...

# %%
data.sort_values(by = "Name", ascending=False)
# Out:
#                 Name                    Team  Number Position  Age Height  \
# 237    Zaza Pachulia        Dallas Mavericks    27.0        C   32   6-11
# 271    Zach Randolph       Memphis Grizzlies    50.0       PF   34    6-9
# 402      Zach LaVine  Minnesota Timberwolves     8.0       PG   21    6-5
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG   24    6-3
# 386  Wilson Chandler          Denver Nuggets    21.0       SF   29    6-8
# ..               ...                     ...     ...      ...  ...    ...
# 312       Al Horford           Atlanta Hawks    15.0        C   30   6-10
# 404    Adreian Payne  Minnesota Timberwolves    33.0       PF   25   6-10
# 328   Aaron Harrison       Charlotte Hornets     9.0       SG   21    6-6
# 356     Aaron Gordon           Orlando Magic     0.0       PF   20    6-9
# 152     Aaron Brooks           Chicago Bulls     0.0       PG   31    6-0
#
#      Weight         College      Salary
# ...

# %%
data.sort_values(by = "Salary", na_position="first")
# Out:
#                 Name                 Team  Number Position  Age Height  \
# 2       John Holland       Boston Celtics    30.0       SG   27    6-5
# 46       Elton Brand   Philadelphia 76ers    42.0       PF   37    6-9
# 171    Dahntay Jones  Cleveland Cavaliers    30.0       SG   35    6-6
# 264    Jordan Farmar    Memphis Grizzlies     4.0       PG   29    6-2
# 269     Ray McCallum    Memphis Grizzlies     5.0       PG   24    6-3
# ..               ...                  ...     ...      ...  ...    ...
# 339       Chris Bosh           Miami Heat     1.0       PF   32   6-11
# 251    Dwight Howard      Houston Rockets    12.0        C   30   6-11
# 33   Carmelo Anthony      New York Knicks     7.0       SF   32    6-8
# 169     LeBron James  Cleveland Cavaliers    23.0       SF   31    6-8
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF   37    6-6
#
#      Weight            College      Salary
# 2     205.0  Boston University         NaN
# ...

# %%
data.sort_values(by = ["Team", "Name"])
# Out:
#                 Name                Team  Number Position  Age Height  Weight  \
# 312       Al Horford       Atlanta Hawks    15.0        C   30   6-10   245.0
# 318  Dennis Schroder       Atlanta Hawks    17.0       PG   22    6-1   172.0
# 323      Jeff Teague       Atlanta Hawks     0.0       PG   27    6-2   186.0
# 309    Kent Bazemore       Atlanta Hawks    24.0       SF   26    6-5   201.0
# 311     Kirk Hinrich       Atlanta Hawks    12.0       SG   35    6-4   190.0
# ..               ...                 ...     ...      ...  ...    ...     ...
# 381  Marcus Thornton  Washington Wizards    15.0       SF   29    6-4   205.0
# 376  Markieff Morris  Washington Wizards     5.0       PF   26   6-10   245.0
# 375     Nene Hilario  Washington Wizards    42.0        C   33   6-11   250.0
# 378  Otto Porter Jr.  Washington Wizards    22.0       SF   23    6-8   198.0
# 379   Ramon Sessions  Washington Wizards     7.0       PG   30    6-3   190.0
#
#           College      Salary
# ...

# %%
data.sort_values(by = ["Team", "Name"], ascending= [True, False])
# Out:
#                  Name                Team  Number Position  Age Height  \
# 322    Walter Tavares       Atlanta Hawks    22.0        C   24    7-3
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG   24    6-6
# 321    Tiago Splitter       Atlanta Hawks    11.0        C   31   6-11
# 320   Thabo Sefolosha       Atlanta Hawks    25.0       SF   32    6-7
# 315      Paul Millsap       Atlanta Hawks     4.0       PF   31    6-8
# ..                ...                 ...     ...      ...  ...    ...
# 374        JJ Hickson  Washington Wizards    21.0        C   27    6-9
# 380    Garrett Temple  Washington Wizards    17.0       SG   30    6-6
# 372       Drew Gooden  Washington Wizards    90.0       PF   34   6-10
# 369      Bradley Beal  Washington Wizards     3.0       SG   22    6-5
# 368     Alan Anderson  Washington Wizards     6.0       SG   33    6-6
#
#      Weight               College      Salary
# 322   260.0                   NaN   1000000.0
# ...
